# %%
# Week 1 — Project Planning and Setup

## Problem Statement
Current navigation systems prioritize shortest or fastest routes, not environmental sustainability.
This project aims to build an AI model that recommends eco-friendly routes minimizing CO₂ emissions.

## Goals
- Create a dataset of routes with vehicle, traffic, and emission data.
- Train a regression model to estimate CO₂ emissions.
- Use graph algorithms to find least-polluting paths.
- Build a prototype Streamlit app.

## Week 1 Tasks
- Define project scope ✅
- Set up environment and folder structure ✅
- Create GitHub repo ✅
- Start preparing dummy dataset (next week)
